# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
fig,axs = plt.subplots(2,3,figsize=(10,10))             #fig is for the figure and ax is for the axis
ax00 = axs[0,0]
ax01= axs[1,0]
#plt.axes(ax)
ax00.plot([0,1,2],[3,4,5],"b--",label = "My label",linewidth = 5)   #strings determine the lines
ax01.plot([3,4,5],[7,8,9])
ax00.set_ylim([0,10])

#line = ax.plot([0,1,2],[3,4,5])
#line[0].set_color("red")
#ax01.set_xscale("log")
ax01.set_yscale("log")
ax00.set_xticks([2])          #ticks adjustment
ax00.set_yticks([5])
ax00.set_xticklabels(["Two"])
ax00.set_title("Example")
fig.suptitle("Example Suptitle")
ax00.set_xlabel("x-axis")
fig.set_facecolor("white")
ax00.legend()
